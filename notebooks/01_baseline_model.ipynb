# %% [markdown]
# # Day 1 — Data + Baseline Model
#
# 1. Load dataset, inspect shape, check class imbalance ratio
# 2. Stratified train/test split
# 3. Baseline: plain logistic regression, no resampling
# 4. Evaluate: precision, recall, F1, PR-AUC (row 1 of benchmark table)
# 5. Note the baseline's failure mode
